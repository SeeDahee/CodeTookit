# %% [markdown]
# # Folium and Mapping
#
# Mapping Community Gardens

# %%
import folium
from folium import plugins
import pandas as pd
import requests
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from xml.etree import ElementTree

# %matplotlib inline

# %%
bins=pd.read_csv('Public_Recycling_Bins.csv')

# %%
bins.head()
# Out:
#   Borough    Site type         Park/Site Name  \
# 0   Bronx  Subproperty         227th St. Plgd
# 1   Bronx  Subproperty    Allerton Ballfields
# 2   Bronx      Outdoor  Arthur Ave & E 187 St
# 3   Bronx     Outdoor         Barstow Mansion
# 4   Bronx  Subproperty     Bradley Playground
#
#                            Address   Latitude  Longitude
# 0       E 227 St/Bronx River Pkway  40.890849 -73.864224
# 1     Allerton Ave & Moshulu Pkway  40.848891 -73.877128
# 2              Arthur Ave & 187 St  40.855570 -73.887565
# 3  895 Shore Road, Pelham Bay Park  40.871864 -73.805549
# 4           2001-2017 Bronx Park E  40.851889 -73.868549

# %%
m = folium.Map([40.7341719,-73.992605], zoom_start=11)

# %%
latlong=bins[['Latitude','Longitude']]

# %%
latlong.head()
# Out:
#     Latitude  Longitude
# 0  40.890849 -73.864224
# 1  40.848891 -73.877128
# 2  40.855570 -73.887565
# 3  40.871864 -73.805549
# 4  40.851889 -73.868549

# %%
latlong[latlong.isnull()==True]
# Out:
#       Latitude  Longitude
# 0    40.727124 -73.978677
# 1          NaN        NaN
# 2    40.796295 -73.947533
# 3    40.798976 -73.940376
# 4    40.729079 -73.983327
# 6    40.847216 -73.885018
# 8    40.723433 -73.980995
# 9    40.664706 -73.987554
# 11   40.724036 -73.980569
# 12   40.724031 -73.981986
# 13   40.683541 -73.915121
# 14   40.823065 -73.916450
# 15   40.756409 -73.871220
# 16   40.725211 -73.977776
# 18   40.825130 -73.913329
# 20   40.659528 -73.906203
# 22   40.725347 -73.991320
# 23   40.694344 -73.946088
# 24   40.721396 -73.979916
# 25   40.683251 -74.003548
# 26   40.665633 -73.913605
# 27   40.693378 -73.946915
# 28   40.836520 -73.885069
# 29   40.852889 -73.901885
# 31   40.673772 -73.878795
# 32   40.722520 -73.990728
# 33   40.728307 -73.978864
# 34   40.683535 -73.792211
# 35   40.689588 -73.803594
# 36   40.682842 -74.006259
# ..         ...        ...
# 495  40.694666 -73.943253
# 497  40.666544 -73.887795
# 499  40.660713 -73.895655
# 500  40.679691 -73.950448
# 501  40.809031 -73.942488
# 502  40.575064 -73.985961
# 503  40.674543 -73.877838
# 504  40.728258 -73.978901
# 505  40.690036 -73.943557
# 506  40.695179 -73.943354
# 507  40.694461 -73.950534
# 508  40.695196 -73.944122
# 512  40.796895 -73.945424
# 514  40.820531 -73.914448
# 515  40.677263 -73.953835
# 516  40.870293 -73.898309
# 517  40.807068 -73.922098
# 518  40.680820 -73.979402
# 519  40.809962 -73.850710
# 520  40.684676 -73.924963
# 522  40.803674 -73.963366
# 524  40.810710 -73.940702
# 525  40.812454 -73.942882
# 526  40.851073 -73.938894
# 527  40.786617 -73.970356
# 528  40.677792 -73.951866
# 529  40.644392 -74.084861
# 531  40.811116 -73.951300
# 534  40.692534 -73.916722
# 535  40.831160 -73.929149
#
# [422 rows x 2 columns]

# %%
final=latlong.dropna()

# %%
final.head()
# Out:
#     Latitude  Longitude
# 0  40.890849 -73.864224
# 1  40.848891 -73.877128
# 2  40.855570 -73.887565
# 3  40.871864 -73.805549
# 4  40.851889 -73.868549

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m = folium.Map(location=[40.7341719,-73.992605])
final.apply(lambda row:folium.Marker(location=[row["Latitude"], 
                                                  row["Longitude"]]).add_to(m),
     axis=1)
# Out:
# 0      <folium.map.Marker object at 0x114597cf8>
# 1      <folium.map.Marker object at 0x114597da0>
# 2      <folium.map.Marker object at 0x114597dd8>
# 3      <folium.map.Marker object at 0x114597e10>
# 4      <folium.map.Marker object at 0x114597e48>
# 5      <folium.map.Marker object at 0x114597e80>
# 6      <folium.map.Marker object at 0x114597eb8>
# 7      <folium.map.Marker object at 0x114597ef0>
# 8      <folium.map.Marker object at 0x114597f28>
# 9      <folium.map.Marker object at 0x11458aef0>
# 10     <folium.map.Marker object at 0x114597f60>
# 11     <folium.map.Marker object at 0x114597f98>
# 12     <folium.map.Marker object at 0x114597fd0>
# 13     <folium.map.Marker object at 0x114597d30>
# 14     <folium.map.Marker object at 0x114597d68>
# 15     <folium.map.Marker object at 0x11445f0b8>
# 16     <folium.map.Marker object at 0x11445f0f0>
# 17     <folium.map.Marker object at 0x11445f128>
# 18     <folium.map.Marker object at 0x11445f160>
# 19     <folium.map.Marker object at 0x11445f198>
# 20     <folium.map.Marker object at 0x11445f1d0>
# 21     <folium.map.Marker object at 0x11445f208>
# 22     <folium.map.Marker object at 0x11445f240>
# 23     <folium.map.Marker object at 0x11445f278>
# 24     <folium.map.Marker object at 0x11445f2b0>
# 25     <folium.map.Marker object at 0x11445f2e8>
# 26     <folium.map.Marker object at 0x11445f320>
# 27     <folium.map.Marker object at 0x11445f358>
# 28     <folium.map.Marker object at 0x11445f390>
# 29     <folium.map.Marker object at 0x11445f3c8>
#                          ...
# 515    <folium.map.Marker object at 0x1144c4f60>
# 516    <folium.map.Marker object at 0x1144c4f98>
# 517    <folium.map.Marker object at 0x1144c4fd0>
# 518    <folium.map.Marker object at 0x1144c4080>
# 519    <folium.map.Marker object at 0x1144c4048>
# 520    <folium.map.Marker object at 0x1144d50b8>
# 521    <folium.map.Marker object at 0x1144d50f0>
# 522    <folium.map.Marker object at 0x1144d5128>
# 523    <folium.map.Marker object at 0x1144d5160>
# 524    <folium.map.Marker object at 0x1144d5198>
# 525    <folium.map.Marker object at 0x1144d51d0>
# 526    <folium.map.Marker object at 0x1144d5208>
# 527    <folium.map.Marker object at 0x1144d5240>
# 528    <folium.map.Marker object at 0x1144d5278>
# 529    <folium.map.Marker object at 0x1144d52b0>
# 530    <folium.map.Marker object at 0x1144d52e8>
# 531    <folium.map.Marker object at 0x1144d5320>
# 532    <folium.map.Marker object at 0x1144d5358>
# 533    <folium.map.Marker object at 0x1144d5390>
# 534    <folium.map.Marker object at 0x1144d53c8>
# 535    <folium.map.Marker object at 0x1144d5400>
# 536    <folium.map.Marker object at 0x1144d5438>
# 537    <folium.map.Marker object at 0x1144d5470>
# 538    <folium.map.Marker object at 0x1144d54a8>
# 539    <folium.map.Marker object at 0x1144d54e0>
# 540    <folium.map.Marker object at 0x1144d5518>
# 541    <folium.map.Marker object at 0x1144d5550>
# 542    <folium.map.Marker object at 0x1144d5588>
# 543    <folium.map.Marker object at 0x1144d55c0>
# 544    <folium.map.Marker object at 0x1144d55f8>
# Length: 544, dtype: object

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m.save(outfile= "bins.html")
